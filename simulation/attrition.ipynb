# %%
import pandas as pd
from pathlib import Path

folder_path = Path('../Data/processed_olympics_data/')

repeat_count = 0
total_count = 0
codes = ["SWA",
"DIV",
"OWS",
"SWM",
"WPO",
"ARC",
"ATH",
"BDM",
"BSB",
"SBL",
"BK3",
"BKB",
"PEL",
"BOX",
"BKG",
"CSP",
"CSL",
"CKT",
"CQT",
"BMF",
"BMX",
"MTB",
"CRD",
"CTR",
"EDR",
"EVE",
"EJP",
"EVL",
"EDV",
"FEN",
"HOC",
"AFB",
"FBL",
"GLF",
"GAR",
"GRY",
"GTR",
"HBL",
"HBL",
"JUD",
"KTE",
"LAX",
"LAX",
"MPN",
"POL",
"RQT",
"ROQ",
"ROC",
"ROW",
"RU7",
"RUG",
"SAL",
"SHO",
"SKB",
"CLB",
"SQU",
"SRF",
"SWA",
"TTE",
"TKW",
"TEN",
"TRI",
"TOW",
"VBV",
"VVO",
"PBT",
"PBT",
"WLF",
"WRF",
"WRG",
"FSK",
"FSK",
"IHO",
"JDP",
"ART",
"ALP",
"AER",
]

output_file = 'attrition_rates.csv'
output_df = pd.DataFrame(columns=['Sport', 'Total athletes', 'Repeat athletes', 'prob_attrition'])
data_list = []
data_list.append({
    "test": "burh",
    "thoeu" : "aaa"
})
# for i in range(0, len(codes)):
#     codes[i]

#     for file in folder_path.iterdir():
#         temp = str(file).split("_")
#         for x in temp:
#             if x == codes[i]:
#                 # print(x)
#                 for index, row in df.iterrows():
#                     total_count += 1
#                     if row['Multiple Events'] == True:
#                         repeat_count += 1
        


#         df = pd.read_csv(file)
#         rows = df.shape[0]
#     # if repeat_count == 0 and total_count == 0: continue
#     # print(codes[i], total_count, repeat_count, repeat_count/total_count)
#     total_count = 0
#     repeat_count = 0

#     if repeat_count == 0 and total_count == 0: continue
#     data_list.append({
#             'Sport': codes[i],
#             'Total athletes': total_count,
#             'Repeat athletes': repeat_count,
#             'prob_attrition': repeat_count/total_count,
#         })
        
output_df = pd.DataFrame(data_list)
output_df.to_csv(output_file, index=False)
